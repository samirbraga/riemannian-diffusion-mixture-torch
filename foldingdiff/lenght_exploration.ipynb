# %%
import pandas as pd
df=pd.read_csv('data/chain_lengths.csv')

# %%
df.describe()
# Out:
#             length
# count  5698.000000
# mean     91.310460
# std      84.548009
# min       1.000000
# 25%      30.000000
# 50%      70.000000
# 75%     125.000000
# max     686.000000
